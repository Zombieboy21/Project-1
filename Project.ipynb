# %%
import itertools as it
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import pandas as pd

# %%
Crime = pd.read_csv('state_crime.csv', usecols = range(0,12))
Crime
# Out:
#         State  Year  Data.Population  Data.Rates.Property.All  \
# 0     Alabama  1960          3266740                   1035.4
# 1     Alabama  1961          3302000                    985.5
# 2     Alabama  1962          3358000                   1067.0
# 3     Alabama  1963          3347000                   1150.9
# 4     Alabama  1964          3407000                   1358.7
# ...       ...   ...              ...                      ...
# 3110  Wyoming  2015           586107                   1902.6
# 3111  Wyoming  2016           585501                   1957.3
# 3112  Wyoming  2017           579315                   1830.4
# 3113  Wyoming  2018           577737                   1785.1
# 3114  Wyoming  2019           578759                   1571.1
#
#       Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                            355.9                        592.1
# 1                            339.3                        569.4
# ...

# %%
Crime['Total Crime Rate'] = Crime['Data.Rates.Property.All'] + Crime['Data.Rates.Violent.All']

# %%
Crime
# Out:
#         State  Year  Data.Population  Data.Rates.Property.All  \
# 0     Alabama  1960          3266740                   1035.4
# 1     Alabama  1961          3302000                    985.5
# 2     Alabama  1962          3358000                   1067.0
# 3     Alabama  1963          3347000                   1150.9
# 4     Alabama  1964          3407000                   1358.7
# ...       ...   ...              ...                      ...
# 3110  Wyoming  2015           586107                   1902.6
# 3111  Wyoming  2016           585501                   1957.3
# 3112  Wyoming  2017           579315                   1830.4
# 3113  Wyoming  2018           577737                   1785.1
# 3114  Wyoming  2019           578759                   1571.1
#
#       Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                            355.9                        592.1
# 1                            339.3                        569.4
# ...

# %%
Crime_Modern = Crime[['State','Year','Total Crime Rate']][(Crime['State']=='Florida') & (Crime['Year'] >= 1980) | (Crime['State']=='New York') & (Crime['Year'] >= 1980) | (Crime['State']=='Texas') & (Crime['Year'] >= 1980) | (Crime['State']=='Illinois') & (Crime['Year'] >= 1980) | (Crime['State']=='California') & (Crime['Year'] >= 1980) ]
Crime_Modern.head(50)
# Out:
#           State  Year  Total Crime Rate
# 260  California  1980            7833.1
# 261  California  1981            7590.5
# 262  California  1982            7285.4
# 263  California  1983            6677.5
# 264  California  1984            6468.4
# 265  California  1985            6518.0
# 266  California  1986            6762.8
# 267  California  1987            6506.4
# 268  California  1988            6635.5
# 269  California  1989            6763.5
# 270  California  1990            6603.6
# 271  California  1991            6772.6
# 272  California  1992            6679.5
# 273  California  1993            6456.9
# 274  California  1994            6173.8
# 275  California  1995            5831.1
# 276  California  1996            5207.8
# 277  California  1997            4865.4
# 278  California  1998            4342.8
# 279  California  1999            3805.0
# 280  California  2000            3739.8
# 281  California  2001            3893.2
# ...

# %%
Crime_Modern = Crime[['State','Year','Total Crime Rate']][(Crime['State']=='') & (Crime['Year'] >= 1980)
